# %% [markdown]
# <a href="https://colab.research.google.com/github/MariaMuu/Thesis/blob/main/Sparql_data_validation_test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
import json
import time
from urllib.parse import quote
import csv

# %%
class WikidataSPARQLValidator:
    def __init__(self):
        self.endpoint = "https://query.wikidata.org/sparql"
        self.headers = {
            'User-Agent': 'SPARQL-Validator/1.0 (your-email@example.com)',
            'Accept': 'application/json'
        }

    def test_query(self, sparql_query):
        """
        Test a single SPARQL query against Wikidata
        Returns: (has_results, result_count, error_message)
        """
        try:
            # Add LIMIT if not present to avoid huge results
            if 'LIMIT' not in sparql_query.upper():
                sparql_query += ' LIMIT 100'

            params = {
                'query': sparql_query,
                'format': 'json'
            }

            response = requests.get(
                self.endpoint,
                params=params,
                headers=self.headers,
                timeout=30
            )

            if response.status_code == 200:
                data = response.json()
                result_count = len(data.get('results', {}).get('bindings', []))
                has_results = result_count > 0
                return has_results, result_count, None
            else:
                return False, 0, f"HTTP {response.status_code}: {response.text[:200]}"

        except requests.exceptions.Timeout:
            return False, 0, "Query timeout"
        except requests.exceptions.RequestException as e:
            return False, 0, f"Request error: {str(e)}"
        except json.JSONDecodeError:
            return False, 0, "Invalid JSON response"
        except Exception as e:
            return False, 0, f"Unexpected error: {str(e)}"

    def validate_dataset(self, qa_pairs, delay=1.0):
        """
        Validate a list of Q&A pairs
        qa_pairs: list of dicts with 'question' and 'sparql' keys
        delay: seconds to wait between requests (be nice to Wikidata!)
        """
        results = []

        for i, pair in enumerate(qa_pairs):
            print(f"Testing query {i+1}/{len(qa_pairs)}: {pair.get('question', 'No question')[:50]}...")

            has_results, count, error = self.test_query(pair['sparql'])

            result = {
                'index': i,
                'question': pair.get('question', ''),
                'sparql': pair['sparql'],
                'has_results': has_results,
                'result_count': count,
                'error': error,
                'status': 'VALID' if has_results else 'INVALID'
            }

            results.append(result)

            # Be nice to Wikidata servers
            time.sleep(delay)

        return results

    def save_results(self, results, filename='sparql_validation_results.csv'):
        """Save validation results to CSV"""
        with open(filename, 'w', newline='', encoding='utf-8') as f:
            writer = csv.DictWriter(f, fieldnames=[
                'index', 'question', 'sparql', 'has_results',
                'result_count', 'error', 'status'
            ])
            writer.writeheader()
            writer.writerows(results)

        print(f"Results saved to {filename}")

    def print_summary(self, results):
        """Print validation summary"""
        total = len(results)
        valid = sum(1 for r in results if r['has_results'])
        invalid = total - valid

        print(f"\n=== VALIDATION SUMMARY ===")
        print(f"Total queries: {total}")
        print(f"Valid (return results): {valid} ({valid/total*100:.1f}%)")
        print(f"Invalid (no results): {invalid} ({invalid/total*100:.1f}%)")

        # Show some examples of invalid queries
        invalid_examples = [r for r in results if not r['has_results']][:5]
        if invalid_examples:
            print(f"\nFirst few invalid queries:")
            for ex in invalid_examples:
                print(f"- Q: {ex['question'][:60]}...")
                print(f"  Error: {ex['error'] or 'No results returned'}")
                print()

# %%
# Example usage:
def load_csv_dataset(filename):
    """Load Q&A pairs from CSV file"""
    qa_pairs = []

    try:
        with open(filename, 'r', encoding='utf-8') as f:
            reader = csv.reader(f)

            for i, row in enumerate(reader):
                if len(row) >= 2:  # Make sure we have at least 2 columns
                    qa_pairs.append({
                        'question': row[0].strip(),
                        'sparql': row[1].strip()
                    })
                else:
                    print(f"Warning: Row {i+1} doesn't have enough columns, skipping")

        print(f"Loaded {len(qa_pairs)} Q&A pairs from {filename}")
        return qa_pairs

    except FileNotFoundError:
        print(f"Error: File '{filename}' not found!")
        return []
    except Exception as e:
        print(f"Error loading CSV: {e}")
        return []

# %%
def main():
    # Load your CSV file
    csv_filename = input("/content/thesis_prompt_test_random.csv").strip()
    if not csv_filename:
        csv_filename = "dataset.csv"

    qa_pairs = load_csv_dataset(csv_filename)

    if not qa_pairs:
        print("No data loaded. Exiting.")
        return

    # Ask if user wants to test all or just a subset
    test_all = input(f"Test all {len(qa_pairs)} queries? (y/n, default=y): ").strip().lower()

    if test_all == 'n':
        try:
            limit = int(input("How many queries to test? "))
            qa_pairs = qa_pairs[:limit]
        except ValueError:
            print("Invalid number, testing first 100...")
            qa_pairs = qa_pairs[:100]

    validator = WikidataSPARQLValidator()

    print(f"Starting SPARQL validation for {len(qa_pairs)} queries...")
    print("This may take a while - we wait 1 second between each query to be nice to Wikidata")

    results = validator.validate_dataset(qa_pairs)

    validator.print_summary(results)

    # Save results with timestamp
    import datetime
    timestamp = datetime.datetime.now().strftime("%Y%m%d_%H%M%S")
    output_filename = f"validation_results_{timestamp}.csv"
    validator.save_results(results, output_filename)

    # Also save just the invalid queries for easy fixing
    invalid_queries = [r for r in results if not r['has_results']]
    if invalid_queries:
        invalid_filename = f"invalid_queries_{timestamp}.csv"
        validator.save_results(invalid_queries, invalid_filename)
        print(f"Invalid queries saved separately to {invalid_filename}")

    return results

if __name__ == "__main__":
    results = main()
# Out:
# /content/thesis_prompt_test_random.csvthesis_prompt_test_random.csv
# Loaded 1501 Q&A pairs from thesis_prompt_test_random.csv
# Test all 1501 queries? (y/n, default=y): y
# Starting SPARQL validation for 1501 queries...
# This may take a while - we wait 1 second between each query to be nice to Wikidata
# Testing query 1/1501: question...
# Testing query 2/1501: What was the capital of the Austrian Empire ?...
# Testing query 3/1501: What Blood test Specialty Type for Academy....
# Testing query 4/1501: When is {diplomatic relation} of {county seat of} ...
# Testing query 5/1501: Which kernel is named after Linux?...
# Testing query 6/1501: Who is die from of Jean-Claude Duvalier, that has ...
# Testing query 7/1501: Name the antonym of opinion that has see also in t...
# Testing query 8/1501: where is the office held by head of government and...
# Testing query 9/1501: What is the other half of the coordinates for the ...
# Testing query 10/1501: Name of the statuette with the lowest thickness wh...
# Testing query 11/1501: Tell me about the history of sovereign India....
# Testing query 12/1501: What what isazane has effect by ammonia exposurean...
# Testing query 13/1501: What characters are in Nineteen Eighty-Four?...
# Testing query 14/1501: What position does Ólafur Ragnar Grímsson hold tha...
# Testing query 15/1501: Are Basra and Kitwe twinned administrative bodies ...
# Testing query 16/1501: Who competed in the battle of Xerxes?...
# Testing query 17/1501: I want to know at what took part of Ralf Schumann?...
# Testing query 18/1501: Is 0.5 the incidence of hepatitis C?...
# Testing query 19/1501: When was Eleftheros Venizelos replaced as Prime Mi...
# Testing query 20/1501: What magazine has the most readers?...
# Testing query 21/1501: Give me the country where the 20th Century Fox hea...
# Testing query 22/1501: What are the feminine/masculine forms in the expre...
# Testing query 23/1501: Tell me medical attribute  whose name has the word...
# Testing query 24/1501: Who are the parent organization and the parent clu...
# Testing query 25/1501: What type of geology of anorthite is monitored by ...
# Testing query 26/1501: Which is the video game series developed by n-Spac...
# Testing query 27/1501: Who replaced Aga Khan III as the Islmaili imam?...
# Testing query 28/1501: What was Cecil Beaton nominated for in 1960?...
# Testing query 29/1501: What borders the Israel Museum?...
# Testing query 30/1501: What was Emmanuelle Riva nominated for in 2013?...
# Testing query 31/1501: What subject did Trey Parker major in at Universit...
# Testing query 32/1501: How many forewords did John Lasseter author?...
# Testing query 33/1501: What is the name of a painting created by Rembrand...
# Testing query 34/1501: who medical specialty for health specialty of diab...
# Testing query 35/1501: Which is {source of inspiration} of {characters} o...
# Testing query 36/1501: What are the fictional location which start with t...
# Testing query 37/1501: For which of her movies Isabelle Adjani also serve...
# Testing query 38/1501: how many are separated from northwest territorires...
# Testing query 39/1501: What is blizzard with the highest amount of snow ?...
# Testing query 40/1501: when s the {point in time} for {Bank of China} has...
# Testing query 41/1501: Name the collective pseudonym that refers to the C...
# Testing query 42/1501: For what work did Ernest Borgnine receive a nomina...
# Testing query 43/1501: Who is the winner for family tiles for the comedy ...
# Testing query 44/1501: WHICH IS THE DOCUMENT THAT STARTS WITH O...
# Testing query 45/1501: What is the compulsory education and the maximum a...
# Testing query 46/1501: Is the installed capacity of Jiangxia Tidal Power ...
# Testing query 47/1501: Tell me military rankw wose name has the word stab...
# Testing query 48/1501: what is the name of a military academy that starts...
# Testing query 49/1501: When was Adrien Brody nominated for the European F...
# Testing query 50/1501: What is the unit of time that has the least Wikida...
# Testing query 51/1501: When did French Polynesia have a population of 223...
# Testing query 52/1501: WHICH IS THE IRRITANT WHICH HAS MAX ELECTRICAL CON...
# Testing query 53/1501: what is academy that starts with u...
# Testing query 54/1501: Is the maximum Strahler number of the Stony Run eq...
# Testing query 55/1501: What is the lowest point of Kerala that has a GPS ...
# Testing query 56/1501: What is the largest set of numbers that include ne...
# Testing query 57/1501: Also known as Richard Neutra's place of death, in ...
# Testing query 58/1501: Is the drag coefficient of the Tesla Model 3 great...
# Testing query 59/1501: Which is the natural script that is used by Arabic...
# Testing query 60/1501: for which of his  work Karl Malden received Academ...
# Testing query 61/1501: What audio language is O Tannenbaum in? The regula...
# Testing query 62/1501: What was Spike Jonze nominated for in the 72nd Aca...
# Testing query 63/1501: Was Sharon_Stone award received 66th Primetime Emm...
# Testing query 64/1501: Who is the rector of Saint Petersburg State Univer...
# Testing query 65/1501: Which airport is the hub of Delta Air Lines?...
# Testing query 66/1501: What is did Johnson & Johnson get on January 25, 2...
# Testing query 67/1501: Does Snoop Dogg speaks, writes  or signs in Old En...
# Testing query 68/1501: What is Ruby in English?...
# Testing query 69/1501: Is Diabetes mellitus studied in diabetology?...
# Testing query 70/1501: What was the population of Clermont-Ferrand on 1-1...
# Testing query 71/1501: How many charges are due to corruption?...
# Testing query 72/1501: Where did Hilary Putnam receive their Ph.D.?...
# Testing query 73/1501: Who are the characters of Adam and Eve?...
# Testing query 74/1501: When did Chiang Mai become the sister city of Sait...
# Testing query 75/1501: What municipal monuments are located at the head o...
# Testing query 76/1501: How much of the intended audience is female?...
# Testing query 77/1501: Who is the organizer for the sport of World Series...
# Testing query 78/1501: Name a trade association that starts with letter A...
# Testing query 79/1501: What is the workplace of Félix Guattari, where the...
# Testing query 80/1501: What are the biomedical measurand which start with...
# Testing query 81/1501: Who gave the{museum collection} of {moveable objec...
# Testing query 82/1501: WHICH IS THE THROUGH STATION WITH THE MAXIMUM NUMB...
# Testing query 83/1501: What is the coat of arms of lithium's findspot?...
# Testing query 84/1501: Is the maximum peak exposure limit of the trichlor...
# Testing query 85/1501: Which is the consortium for the member of Universi...
# Testing query 86/1501: "Who is the namesake of Van der Waals equation, wh...
# Testing query 87/1501: Which video game company produced Pong?...
# Testing query 88/1501: What is the county seat of Polokwane, which was co...
# Testing query 89/1501: Name the architectural style pattern of Nocturne: ...
# Testing query 90/1501: What is the parent organization and owner of UNICE...
# Testing query 91/1501: Who is the head of Cern ?...
# Testing query 92/1501: What is the two-part administrative body of Milwau...
# Testing query 93/1501: What does Fahrenheit measure?...
# Testing query 94/1501: When did Glen Campbell receive a Grammy Hall of Fa...
# Testing query 95/1501: How many doctoral advisors are determined for Gott...
# Testing query 96/1501: What is on harbour on the Reykjavik, whose tributa...
# Testing query 97/1501: What is the name of the capital city of South Aust...
# Testing query 98/1501: What royal or noble rank does the head of state of...
# Testing query 99/1501: Which female actress is the voice over on South Pa...
# Testing query 100/1501: who is the  doctoral student   of louis _pasteur?...
# Testing query 101/1501: What was the alma mater of the author of "Schizoph...
# Testing query 102/1501: When did Dominik Hašek become a citizen of Czechos...
# Testing query 103/1501: Which universe does Star Trek take place?...
# Testing query 104/1501: Which is the mineral species which starts with the...
# Testing query 105/1501: Who replaced Vespasian as Roman emperor?...
# Testing query 106/1501: Where is the National Rifle Association's headquar...
# Testing query 107/1501: In what year did Rush Limbaugh's pet, named Punkin...
# Testing query 108/1501: who was the spouse of Carl Jung as at 1955-0-0?...
# Testing query 109/1501: Is Narcissistic personality disorder a health spec...
# Testing query 110/1501: Who was the previous top dog of 1991 Mr. Olympia?...
# Testing query 111/1501: who state of austria for twinned administrative bo...
# Testing query 112/1501: Who started a conflict by overthrowing Idi Amin?...
# Testing query 113/1501: What is played by the the extended form of the gen...
# Testing query 114/1501: Did Bitcoin come from Sardinia?...
# Testing query 115/1501: Which is {history} of {plays} of {Lenin Guerra Tul...
# Testing query 116/1501: Who replaced William Murray, first Earl of Mansfie...
# Testing query 117/1501: What street in Palacio dos Grilos Rua da IIha loca...
# Testing query 118/1501: "What country is adjacent to Murcia that has 20402...
# Testing query 119/1501: Is the vertical depth of the CHairburun equal to 0...
# Testing query 120/1501: What is the subcellular localization code for Cdc4...
# Testing query 121/1501: Is it true that the volume as quantity of the femt...
# Testing query 122/1501: When did Portsmouth have a population of 248440?...
# Testing query 123/1501: In 2003-0-0, what was Ole Einar Bjorndalen nominat...
# Testing query 124/1501: What landlocked country that is a member of the Un...
# Testing query 125/1501: What is the maximum length of Lake Baikal?...
# Testing query 126/1501: When did Adunis win the Janus Pannonius Internatio...
# Testing query 127/1501: Is the coma cluster flux 2.5536e-10 or greater?...
# Testing query 128/1501: What quantity is measured in degree Fahrenheit?...
# Testing query 129/1501: Who is the {academic discipline} for {partially co...
# Testing query 130/1501: Tell me comic book series whose name has the word ...
# Testing query 131/1501: In which year did the Louvre Museum have 8.6 milli...
# Testing query 132/1501: What is the domain of Scandinavian literature whos...
# Testing query 133/1501: Was William_Wallace conflict Wars of Scottish Inde...
# Testing query 134/1501: Is the maximum peak exposure limit of styrene equa...
# Testing query 135/1501: What revolution caused the destruction of the Russ...
# Testing query 136/1501: What percentage of Angola's population is European...
# Testing query 137/1501: How did Henry VIII and Catherine Parr's marriage e...
# Testing query 138/1501: What is the allotrope of carbon that makes crystal...
# Testing query 139/1501: Which prescribed drug for epilepsy has a weight of...
# Testing query 140/1501: Which of Joachim Murat's Kids wrote language in Fr...
# Testing query 141/1501: Is the number of blank votes in the Rio Grande mun...
# Testing query 142/1501: When will Triple H return to Wrestle Mania?...
# Testing query 143/1501: What is the forename of John Ames Mitchell that is...
# Testing query 144/1501: What is Franklin Pierce's a United States represen...
# Testing query 145/1501: The individual who discovered pulsar is in which f...
# Testing query 146/1501: When did Galeazzo Ciano become the minister of For...
# Testing query 147/1501: What is the name of a platonic solid, which is of ...
# Testing query 148/1501: For what piece of work was Willie Nelson nominated...
# Testing query 149/1501: What are the nishiki-e which start with the letter...
# Testing query 150/1501: When was Jacques Anquetil received the award as L'...
# Testing query 151/1501: What was the population of Argenteuil in 1856?...
# Testing query 152/1501: What Han Chinese person has the largest net worth?...
# Testing query 153/1501: Which is the God in the series of Balabhadra and s...
# Testing query 154/1501: What do you call a citizen of Belgium?...
# Testing query 155/1501: WHAT ARE THE CAT BREED WHOSE NAME HAS THE WORD TOY...
# Testing query 156/1501: What are the ends that are informed by baroque?...
# Testing query 157/1501: Tell me  tournament whose name has the word  weltk...
# Testing query 158/1501: Does the tensile modulus of elasticity of AKROLOY ...
# Testing query 159/1501: Who performed Symphony No. 9 for the first time on...
# Testing query 160/1501: What version is stable version of Tencent QQ?...
# Testing query 161/1501: Which city is the capital of England?...
# Testing query 162/1501: What type of award was received by Peter Debye in ...
# Testing query 163/1501: Name a novella published by Blackwood's Magazine t...
# Testing query 164/1501: How many matches did Majed Abdullah play for the S...
# Testing query 165/1501: What is the introduction period of Siege of Lening...
# Testing query 166/1501: Who is the partner and child of Constantine V?...
# Testing query 167/1501: For what film did Christopher Nolan receive the no...
# Testing query 168/1501: The Hittites ethnic group has what mythology?...
# Testing query 169/1501: What was the population of the Komi Republic in th...
# Testing query 170/1501: Where are the signs of soman exposure found?...
# Testing query 171/1501: how many records were held for  sports event of  k...
# Testing query 172/1501: What is the birthplace of Lucia Moholy. It is wher...
# Testing query 173/1501: WHICH IS THE CITY OF INDONESIA THAT STARTS WITH Y...
# Testing query 174/1501: Is the MV Loch Tarbert gross tonnage less than 168...
# Testing query 175/1501: WHICH IS THE SOCIAL CLASS THAT STARTS WITH Z...
# Testing query 176/1501: Who are the founders of Onyanko Club that speak na...
# Testing query 177/1501: What is the ideology of party member Nigel Farage?...
# Testing query 178/1501: What is the manner and place of death of Dave Mirr...
# Testing query 179/1501: What is the historical language in Guyana?...
# Testing query 180/1501: Was United States Declaration of Independence sign...
# Testing query 181/1501: What is the twinned administrative body in Chennai...
# Testing query 182/1501: Which computer network protocol replaced version 4...
# Testing query 183/1501: How many people does Halle have?...
# Testing query 184/1501: Tell me town whose name has the word sturovo in it...
# Testing query 185/1501: Name the Privately held company with the minimum t...
# Testing query 186/1501: What communist party's name starts with the letter...
# Testing query 187/1501: Who are the authors of Corpus Juris Civilis, writt...
# Testing query 188/1501: Name a symphony composed by Pyotr Ilyich Tchaikovs...
# Testing query 189/1501: When was Zimbabwe's population at 1.25037e+07?...
# Testing query 190/1501: Does Kolasib district have a rural population equa...
# Testing query 191/1501: In what field was Artemidorus of Tralleis employed...
# Testing query 192/1501: Is the female population of The Spectacles less th...
# Testing query 193/1501: When was Fedor Tokarev awarded the Order of Suvoro...
# Testing query 194/1501: Which player competes in Joan Miro?...
# Testing query 195/1501: What is United States headquarters location for Kr...
# Testing query 196/1501: What archaeological period starts with the letter ...
# Testing query 197/1501: For what work, Geena Davis was awarded Academy Awa...
# Testing query 198/1501: The consequence of this autoimmune disease is?...
# Testing query 199/1501: Did Alanis Morissette get nominated for the MTV Vi...
# Testing query 200/1501: What are the protests of the war  that uses the M-...
# Testing query 201/1501: Indra Nooyi is the CEO of what business?...
# Testing query 202/1501: What is less than the consequence of sublimation?...
# Testing query 203/1501: Who did Shirley Jackson marry in 1940?...
# Testing query 204/1501: Pinterest is the owner of what web service?...
# Testing query 205/1501: When did John Searle receive the National Humaniti...
# Testing query 206/1501: Was Tony Curtis nominated for an Academy Award for...
# Testing query 207/1501: Which part of Saratov ended in 1936-12-4?...
# Testing query 208/1501: Who is/are the {authors} of {The Man with Two Face...
# Testing query 209/1501: What field of career is Frédéric Bolley career?...
# Testing query 210/1501: how many bug tracking systems does tencent qq have...
# Testing query 211/1501: Which is impounded by the remake of Toshka Lakes?...
# Testing query 212/1501: Tell me me a automobile marque whose name consist ...
# Testing query 213/1501: Tell me halide anion whose name has the word ion i...
# Testing query 214/1501: WHO IS INTRODUCED FROM INTERNATIONAL PRACTICAL SHO...
# Testing query 215/1501: In what borough is the capital of Kolhar?...
# Testing query 216/1501: How much tax revenue did Zamboangna collect in 201...
# Testing query 217/1501: Is the total equity in Delta Air Lines equal to 24...
# Testing query 218/1501: Does the  ethanol combustion enthalpy less than -1...
# Testing query 219/1501: When did Novak Djokovic become a professional tenn...
# Testing query 220/1501: Who is the taxon parent of manatee having a common...
# Testing query 221/1501: What is the significance of artists of The Beatles...
# Testing query 222/1501: What is the tonal system of the Cantonese language...
# Testing query 223/1501: What are the area of mathematics which start with ...
# Testing query 224/1501: Who is in voivodership of Asyut Governorate, that ...
# Testing query 225/1501: Anna Netrebko has how many roles?...
# Testing query 226/1501: What is the prescribed drug of the murder method o...
# Testing query 227/1501: How many people have the given name Andrew?...
# Testing query 228/1501: What was the residence of Kurt Weill in the year 1...
# Testing query 229/1501: What are the signs or symptoms of hydrogen sulfide...
# Testing query 230/1501: What newspaper is found in the Russian Empire?...
# Testing query 231/1501: What is the residence of Alicia Alonso born at 193...
# Testing query 232/1501: WHat is the religious text that can be translated ...
# Testing query 233/1501: Who is the voice actor for Futurama...
# Testing query 234/1501: What is made from a source of Triticum spelta?...
# Testing query 235/1501: tell me eonothem name has the word proterozoic in ...
# Testing query 236/1501: How was it determined that Puerto Princessa has a ...
# Testing query 237/1501: What battle did the characters of The Divine Comed...
# Testing query 238/1501: What is someone who creates manga as a profession ...
# Testing query 239/1501: What year did Thomas Young, who was head of govern...
# Testing query 240/1501: Tell me civil war whose name has the word war in i...
# Testing query 241/1501: Which {exchange} is {developed by} {File Allocatio...
# Testing query 242/1501: what is the determination method of Genome-wide ge...
# Testing query 243/1501: What is the office of the head of the organization...
# Testing query 244/1501: What is the population of Aleppo as determined in ...
# Testing query 245/1501: What is the portrait of Thomas Lawrence's major wo...
# Testing query 246/1501: What unit of time starts with "z"?...
# Testing query 247/1501: Charles the Bald has how many noble titles?...
# Testing query 248/1501: Name the endorsement sponsored by Republic of Irel...
# Testing query 249/1501: What is the surname of Keiko Matsuzaka, whose audi...
# Testing query 250/1501: Do Prehistoric Egypt and Predynastic period of Egy...
# Testing query 251/1501: Jupiter has a parent astronomical body with which ...
# Testing query 252/1501: Did Hillary Clinton participate in 2006 United Sta...
# Testing query 253/1501: What is first language of Dirk Nowitzki ?...
# Testing query 254/1501: What town is the birthplace of Joseph Greenberg?...
# Testing query 255/1501: Which is the treatment that treats the medical con...
# Testing query 256/1501: Who has won Fred Ebb award?...
# Testing query 257/1501: When was the subsidiaries of Universite de Montrea...
# Testing query 258/1501: Is Brian Wilson relative to Stan Love}...
# Testing query 259/1501: Was Percy Bysshe Shelley a citizen of Great Britai...
# Testing query 260/1501: How many fastest lap times are held by Lewis Hamil...
# Testing query 261/1501: Where is the medals of the artist who inspired thi...
# Testing query 262/1501: who standards setting organisation of language of ...
# Testing query 263/1501: What is made by Webby?...
# Testing query 264/1501: When did Leon Lai and Gaile Lok marry?...
# Testing query 265/1501: Which is the cadastre commissioned by William the ...
# Testing query 266/1501: Who is the {business} for {founded by} of {Ingvar ...
# Testing query 267/1501: Who is the sister of daddy Abaqa Khan?...
# Testing query 268/1501: Is the Platu 25 beam equal to 2.56?...
# Testing query 269/1501: What is a member of  Aleksandr Lapunov.which has w...
# Testing query 270/1501: For what event did Kevin Kuske receive a silver me...
# Testing query 271/1501: What is the prevalence of tuberculosis?...
# Testing query 272/1501: Who is the champion of Frederick Sumner McKay?...
# Testing query 273/1501: When did Mark Rothko become a citizen of the Unite...
# Testing query 274/1501: Which is the subsidiary company that is managed by...
# Testing query 275/1501: What was Julie Harris nominated for in 1976?...
# Testing query 276/1501: What award did David Geffen receive in the year 19...
# Testing query 277/1501: What is a Devi that starts with the letter v....
# Testing query 278/1501: What is the lighthouse range of the Heidenstam lig...
# Testing query 279/1501: What is the latest date recorded for Hafez whose d...
# Testing query 280/1501: Is the longest life span of Homo sapiens less than...
# Testing query 281/1501: Who did Napoleon marry in 1810?...
# Testing query 282/1501: How many out of school children were there in Rafe...
# Testing query 283/1501: Which kidney artery has official name arteria rena...
# Testing query 284/1501: What is the grammatical gender of the language And...
# Testing query 285/1501: What was the population of Manaus at the start of ...
# Testing query 286/1501: What is the location of death of Antipater, whose ...
# Testing query 287/1501: Who is employed by Ernesto Zedillo, who is a membe...
# Testing query 288/1501: what are realm of the death which start with the l...
# Testing query 289/1501: Which is the moveable object location of the Battl...
# Testing query 290/1501: What education received by Matt Groening in the ye...
# Testing query 291/1501: What medicine treats chickenpox?...
# Testing query 292/1501: What is the regional government of Tasmania...
# Testing query 293/1501: Tell me the medication which contains the word ver...
# Testing query 294/1501: What are the taxation which start with the letter ...
# Testing query 295/1501: Who gave the {notable books} of {written by} of {A...
# Testing query 296/1501: What day of the week is preceded by Easter?...
# Testing query 297/1501: What translator is used for editing HTML5?...
# Testing query 298/1501: how many  domain of saint  or deity is for saint n...
# Testing query 299/1501: Where was the birth place of Grazia Deledda?...
# Testing query 300/1501: Who was Jonathan Pryce's partner beginning in 1974...
# Testing query 301/1501: Who replaced Francis Bacon as Attorney General for...
# Testing query 302/1501: How many location does astronomical bodies in  {Ph...
# Testing query 303/1501: Tell me the name of the bank that starts with "u"....
# Testing query 304/1501: When did Vincent Auriol stop being the Minister of...
# Testing query 305/1501: What is the name of the talk show produced by Elle...
# Testing query 306/1501: How many attractions are there in Grenoble?...
# Testing query 307/1501: What degree did Katherine Dunham earn at the Unive...
# Testing query 308/1501: How many students are studying in {geology} ?...
# Testing query 309/1501: At what point in time Baja California had the popu...
# Testing query 310/1501: When did Al-Mansur end his rule as Abbasid Caliph?...
# Testing query 311/1501: Which is typology  language native of Søren Kierke...
# Testing query 312/1501: is the radius of Messier 10 more than 32.0?...
# Testing query 313/1501: Who is Maharashtra's head of government and the he...
# Testing query 314/1501: When was George C. Scott nominated for Tony Award ...
# Testing query 315/1501: What was Ancient Egypt;s former dynasty called?...
# Testing query 316/1501: Is the relative permeability of neodymium magnet e...
# Testing query 317/1501: Name the significance of county of Saskatchewan an...
# Testing query 318/1501: What is the Greek letter for PI...
# Testing query 319/1501: What type of patron was Napoleon?...
# Testing query 320/1501: What continent is Orange Free State with Women in ...
# Testing query 321/1501: Who is the person as secretary general of Social D...
# Testing query 322/1501: What is the profession related to set theory?...
# Testing query 323/1501: what is the source of watercourse of the Fraser Ri...
# Testing query 324/1501: Who is Gottfried Wilhelm Leibniz's doctor...
# Testing query 325/1501: When was Tom Wolfe awarded with the Dos Passos Pri...
# Testing query 326/1501: Is Brooklyn that has cities the birth location of ...
# Testing query 327/1501: Was Jessica Chastain nominated for Academy Award f...
# Testing query 328/1501: Name a bridge designed by Isambard Kingdom Brunel...
# Testing query 329/1501: What is happening at the  Rijksmuseum located at M...
# Testing query 330/1501: What is the continent of Jalgaon whose time zone i...
# Testing query 331/1501: Which medicines have a major drug interaction with...
# Testing query 332/1501: What is the language spoken in the city which Rona...
# Testing query 333/1501: What is the birth palace of Priyanka Chopra,that h...
# Testing query 334/1501: What is the {syllabary} for {writing system} of {J...
# Testing query 335/1501: Which continent did Douglas Adams live in?...
# Testing query 336/1501: When did Michelangelo finish his work in Rome?...
# Testing query 337/1501: What was the birth name of Ayn Rand?...
# Testing query 338/1501: What was Arthur Penn nominated for at the 12th Ann...
# Testing query 339/1501: Name acity whose patron Saint is Paul and that con...
# Testing query 340/1501: For what work did Gig Young receive an Academy Awa...
# Testing query 341/1501: Which city, twinned with Steinhagan, is the place ...
# Testing query 342/1501: Is it true that the duration of the 2079-2080 one-...
# Testing query 343/1501: When did the Tokushima Prefecture have a populatio...
# Testing query 344/1501: How much does Primavera depict?...
# Testing query 345/1501: What are the comics character that contributor(s) ...
# Testing query 346/1501: Was Zayn Malik a member of Manic Street Preachers?...
# Testing query 347/1501: What is being {studied} which is {opposite of} of ...
# Testing query 348/1501: What point divides into the Rhineland-Palatinate, ...
# Testing query 349/1501: What is the cause of diesel in chisels?...
# Testing query 350/1501: Is it true that water colored Seal?...
# Testing query 351/1501: What is Siggy Flickers Field of work?...
# Testing query 352/1501: Whom did Oliver Cromwell get married to?...
# Testing query 353/1501: Mention the position which President of Poland hel...
# Testing query 354/1501: How many times has Joseph Barbera been an executiv...
# Testing query 355/1501: What is the discography for My Chemical Romance?...
# Testing query 356/1501: What is Snow White's name...
# Testing query 357/1501: Who was the creator of Looney Tunes?...
# Testing query 358/1501: What movie was Twelfth Night based on?...
# Testing query 359/1501: What is the discography for Justin Timberlake's di...
# Testing query 360/1501: What is the telephone number of Garrison in the ML...
# Testing query 361/1501: What is the name of the player that competes in It...
# Testing query 362/1501: What nominations was the Shawshank Redemption up f...
# Testing query 363/1501: What office does Mauricio Macri hold?...
# Testing query 364/1501: When did Nîmes have Brunswick as its twinned admin...
# Testing query 365/1501: Which star of The Ed Sullivan Show is an autobiogr...
# Testing query 366/1501: Who gave the{established by} of {member of} of {Er...
# Testing query 367/1501: When was the award received by Santiago calatrava ...
# Testing query 368/1501: Did Howard Stern work as a TV presenter and radio ...
# Testing query 369/1501: Does 0 mean the same as zero?...
# Testing query 370/1501: Which spot came from the Ebola virus?...
# Testing query 371/1501: Is it true that gautama buddha is student of khema...
# Testing query 372/1501: Tell me me a artistic theme whose name consist of ...
# Testing query 373/1501: What are the dog breed which start with the letter...
# Testing query 374/1501: Tell me the number of superhuman feature or abilit...
# Testing query 375/1501: Who composed Unchained Melody ?...
# Testing query 376/1501: The Soviet Union used what type of weaponry?...
# Testing query 377/1501: Whose motion picture studio is a part of series of...
# Testing query 378/1501: How many targets do police officers have?...
# Testing query 379/1501: Is the age of majority in Poland greater than 21.6...
# Testing query 380/1501: Is it true that the minimal incubation period in h...
# Testing query 381/1501: Who is the {immunology} {specialist} that {develop...
# Testing query 382/1501: Was the significant event of Augusto Pinochet his ...
# Testing query 383/1501: Name an animated movie involving Randy Fullmer tha...
# Testing query 384/1501: Name a food ingredient that starts with letter Z...
# Testing query 385/1501: Game of Thrones taes place in which fictional univ...
# Testing query 386/1501: On which mission did Neil Armstrong land on the mo...
# Testing query 387/1501: Who are the inhabitants of the land of Molise?...
# Testing query 388/1501: Which character in Star Wars is killed by Luke Sky...
# Testing query 389/1501: Name the work location of Augustin-Louis Cauchy th...
# Testing query 390/1501: What are the war of national liberation which star...
# Testing query 391/1501: WHICH IS THE CLASS IC FLAMMABLE LIQUID WITH THE MA...
# Testing query 392/1501: did vladimir putin perticipate in 1999-12-31?...
# Testing query 393/1501: What is the sexuality of the winner of MTV Video M...
# Testing query 394/1501: When did xkcd win the Hugo Award for Best Graphic ...
# Testing query 395/1501: Does chicken has a heart rate equal to 275?...
# Testing query 396/1501: Tell me alcohol whose name has the word ynol in it...
# Testing query 397/1501: Which {history} {subject} of {Ilmar Koppel} ?...
# Testing query 398/1501: Which garrison of the International Organization f...
# Testing query 399/1501: Who are the director and director of photography o...
# Testing query 400/1501: Robert Hooke attended which university with a Grad...
# Testing query 401/1501: Which is the building that is commissioned by Univ...
# Testing query 402/1501: What is apparent magnitude of Messier 106 that is ...
# Testing query 403/1501: What is the birthplace of Ahmad al-Mansur whose tw...
# Testing query 404/1501: Tell me cryptocurrency whose name has the word zer...
# Testing query 405/1501: What are the gene which start with the letter t...
# Testing query 406/1501: How many times does carbon-14 decay?...
# Testing query 407/1501: What is the first minister of the place of the act...
# Testing query 408/1501: what position did Harthacanute hold when he was re...
# Testing query 409/1501: Which is the constitution which starts with the le...
# Testing query 410/1501: Which organizations were involved in the Cold War ...
# Testing query 411/1501: When did René Clair receive the Louis Delluc Prize...
# Testing query 412/1501: What is the taxon parent of Cannabis sativa, which...
# Testing query 413/1501: When did Austen Chamberlain become a Member of the...
# Testing query 414/1501: what us the protype aircraft model with the lowest...
# Testing query 415/1501: Who is {disciple} and {professional partner} of {R...
# Testing query 416/1501: What is the filmography and discography of Kylie M...
# Testing query 417/1501: Is the foreign direct investment net outflow of Be...
# Testing query 418/1501: na...
# Testing query 419/1501: What was Rick Baker nominated for for Coming to Am...
# Testing query 420/1501: What model is used for genetic sudies?...
# Testing query 421/1501: Does Ed Sheeran have red hair?...
# Testing query 422/1501: How are Stanisław August Poniatowski and Józef Pon...
# Testing query 423/1501: Who became the chief executive officer of Advanced...
# Testing query 424/1501: How do you address the head or the supreme authori...
# Testing query 425/1501: What series did Robert Guillaume play Robert?...
# Testing query 426/1501: What nomination was received by Kurt Weill, but wo...
# Testing query 427/1501: Who gave the{instrument played} of {play} of {1930...
# Testing query 428/1501: Residents of Venice are called what?...
# Testing query 429/1501: Is it true that the maximum age of the Comparison ...
# Testing query 430/1501: Tell me Protestantism whose name has the word hugu...
# Testing query 431/1501: Where was Lujo Brentano a student of Johann von He...
# Testing query 432/1501: Who is {musician} of {predecessor} {In My Quiet Ro...
# Testing query 433/1501: Who is the person as the head of government of Lvi...
# Testing query 434/1501: What head of government of Cape Town started 05-12...
# Testing query 435/1501: What award did Ayana Hirsi Ali receive in 2008?...
# Testing query 436/1501: Is the quantity of the CFR DE 241 class more than ...
# Testing query 437/1501: Name a {land-grant university} that {affiliation} ...
# Testing query 438/1501: Who is the leader of the Robert A. Heinlein award?...
# Testing query 439/1501: what are the fossil taxon was starts with z...
# Testing query 440/1501: What are the area of engineering which start with ...
# Testing query 441/1501: Are the number of platform tracks of the Times Squ...
# Testing query 442/1501: Rudolf Augstein competed for what office that he h...
# Testing query 443/1501: Name the primary bacterial infectious disease with...
# Testing query 444/1501: Who is incumbent of the position of William Jennin...
# Testing query 445/1501: What re the materials used to make a submarine and...
# Testing query 446/1501: Which is the borough in the United Kingdom that co...
# Testing query 447/1501: Give the swiss federal popular initiative with the...
# Testing query 448/1501: What is Charles Dickens most acclaimed workk?...
# Testing query 449/1501: What was the name of the position held by François...
# Testing query 450/1501: Which two cities in Vancouver are consider its cap...
# Testing query 451/1501: Does the yield strength of the Alloy 718 equal 828...
# Testing query 452/1501: In what mountain range is Mt. Anhui located?...
# Testing query 453/1501: DOES THE OPTIMUM VIABLE TEMPERATURE OF THE PSEUDOM...
# Testing query 454/1501: Apollo 13 was nominated for and won which awards?...
# Testing query 455/1501: Tell me about the French head of state, Emmanuel M...
# Testing query 456/1501: Is Anderson Cooper's mother Gloria Vanderbilt?...
# Testing query 457/1501: Was evolutionary computation follows pattern recog...
# Testing query 458/1501: Name the character role played by Bobby Ewing as a...
# Testing query 459/1501: Which is the digital distribution platform that us...
# Testing query 460/1501: Is the ceiling exposure limit of chloromethyl meth...
# Testing query 461/1501: how many authors have there been for the new testa...
# Testing query 462/1501: What number month of the year is December?...
# Testing query 463/1501: Was Marilyn_Manson genre Deathrock?...
# Testing query 464/1501: What are the doll which start with the letter t...
# Testing query 465/1501: Who are the writers of the Sermon on the Mount, wh...
# Testing query 466/1501: What is the position of Thomas Jefferson that is b...
# Testing query 467/1501: At what point in time did Northern England have a ...
# Testing query 468/1501: What is Filippo Brunelleschi's birthday, given tha...
# Testing query 469/1501: "Which is {county seat} of {Kalimantan Barat}, who...
# Testing query 470/1501: Does Iullus Antonius have a father and brother?...
# Testing query 471/1501: What is the native language of the Circassians?...
# Testing query 472/1501: Who replaced Pius XII as the Camerlengo of the Sac...
# Testing query 473/1501: What religion does the sister of Basil of Caesarea...
# Testing query 474/1501: Who is born at Bertha Benz, whose inhabitants is 1...
# Testing query 475/1501: How many military branches are with the Erwin Romm...
# Testing query 476/1501: Who did Greer Garson marry on January 1, 1943?...
# Testing query 477/1501: What is Hans Eysenck's name that the same first na...
# Testing query 478/1501: Was Grace Jones nominated for a Golden Raspberry A...
# Testing query 479/1501: When did Rowan Atkinson attend the Queen's College...
# Testing query 480/1501: What is the motor yacht with the highest gross ton...
# Testing query 481/1501: What is in the territory of Bakhtiarov?...
# Testing query 482/1501: What is the determination method that Bilbao has t...
# Testing query 483/1501: What was the source of Thales' death on 1-1-546?...
# Testing query 484/1501: Which is in the endemism of Reunion Stonechat...
# Testing query 485/1501: How many executive producers are there on The West...
# Testing query 486/1501: Tell me statute whose name has the word zuteilungs...
# Testing query 487/1501: Where did Hugo Pratt move from on August 20, 1995?...
# Testing query 488/1501: For what Juan Antonio Samarnch held the position i...
# Testing query 489/1501: What country was Józef Piłsudski a citizen of at t...
# Testing query 490/1501: Does the patronage of the Kastamonu Airport equal ...
# Testing query 491/1501: In what part of the Netherlands is the Erasmus Uni...
# Testing query 492/1501: Who did the illustrations for the J. R. R. Tolkien...
# Testing query 493/1501: who is the discography and filmography of Clint_Ea...
# Testing query 494/1501: What painter of Maoism died in Zhongnanhai?...
# Testing query 495/1501: Which public company has the largest number of reg...
# Testing query 496/1501: who is inspiration to son of ben?...
# Testing query 497/1501: Tell me the bell tower that starts with the letter...
# Testing query 498/1501: Who was Erich Maria Remarque's spouse from 1925-0-...
# Testing query 499/1501: Who was Johnny Depp's partner until 1993?...
# Testing query 500/1501: How many nicknames does Louisiana have?...
# Testing query 501/1501: Name the shipwreck with highest beam?...
# Testing query 502/1501: What church building was constructed by Dutch East...
# Testing query 503/1501: What is the sister town of Nara whose geocoordinat...
# Testing query 504/1501: What is manufactured NEC PC-9800 series whose sect...
# Testing query 505/1501: Which co-founder works for Christine Jones?...
# Testing query 506/1501: Is Graham Mink's total career points equal to 0?...
# Testing query 507/1501: What continent is East Asia located in?...
# Testing query 508/1501: What school was attended by Irving Penn, created i...
# Testing query 509/1501: when did richard owen receive the wollaston medal ...
# Testing query 510/1501: What are the chemical compound which start with th...
# Testing query 511/1501: What are the painting technique which start with t...
# Testing query 512/1501: What day of the week is Labour day?...
# Testing query 513/1501: What is the NFPA Health safety classification and ...
# Testing query 514/1501: How many artists made the storyboards for The Lion...
# Testing query 515/1501: Name the G type main sequence star with the larges...
# Testing query 516/1501: Did the Lion make a roar?...
# Testing query 517/1501: How is bipolar disorder diagnosed for with the WSC...
# Testing query 518/1501: What chemical substance is named after sperm whale...
# Testing query 519/1501: If the point group is cubic-hexoctahedral, what is...
# Testing query 520/1501: When was Irish an official language of the Europea...
# Testing query 521/1501: Which is {notation} and the {child astronomical bo...
# Testing query 522/1501: For what work did Poul Anderson receive the Promet...
# Testing query 523/1501: What time does Arthur Cayley, member of the Royal ...
# Testing query 524/1501: When did Rufina Pukhova and Kim Philby get married...
# Testing query 525/1501: "Where is {salon} of {Tiddlywinks}, which has {est...
# Testing query 526/1501: What is the partner city of Khujand, that has a hu...
# Testing query 527/1501: What genetic association did the Genome-wide assoc...
# Testing query 528/1501: who mortally wounded by of motif of the awakening ...
# Testing query 529/1501: Who is the actress in the narrative of Moses?...
# Testing query 530/1501: What is the street address for Manneken Pis where ...
# Testing query 531/1501: Which is AWLD status of  official language of Maml...
# Testing query 532/1501: What is {said to be the same as} and the {opposite...
# Testing query 533/1501: What position did Frank B. Kellogg hold starting o...
# Testing query 534/1501: Name the lethal excipient mad eof chemical compoun...
# Testing query 535/1501: Is it true that the total shots in career of Pette...
# Testing query 536/1501: Does the Dundonald have 3.2 masts?...
# Testing query 537/1501: What are the art museum which start with the lette...
# Testing query 538/1501: How many of the deepest points are in the Persian ...
# Testing query 539/1501: Where did Candice Bergen graduate from and what ha...
# Testing query 540/1501: When did Latvia have 10,293 out of school children...
# Testing query 541/1501: who were the  memberr  and creater of   green _lan...
# Testing query 542/1501: who bridge for architect of Isambard Kingdom Brune...
# Testing query 543/1501: : Does King Solomon's Mines hasnumber of episodes ...
# Testing query 544/1501: Tell me festival whose name has the word vijayadas...
# Testing query 545/1501: what is geochronological unit starts with s...
# Testing query 546/1501: who leader  of Carolyne Wright ?...
# Testing query 547/1501: When did Oscar Robertson receive the All-NBA Team ...
# Testing query 548/1501: Does the picometer of the conversion to SI equal 0...
# Testing query 549/1501: Who were the students of Caspar David Friedrich?...
# Testing query 550/1501: Is it true that Eric Clapton played the guitar?...
# Testing query 551/1501: What was the electorate of Muntinlupa on April 28,...
# Testing query 552/1501: How many means of locomotion are powered by bipeda...
# Testing query 553/1501: What manufacturer is a subsidiary of the National ...
# Testing query 554/1501: Who is the telescope operator for California Insti...
# Testing query 555/1501: Were the Middle Ages followed by the High Middle A...
# Testing query 556/1501: When did Smita Patil receive the National Film Awa...
# Testing query 557/1501: Which powder has the greatest emissivity?...
# Testing query 558/1501: When was the year of death of the coined of boron?...
# Testing query 559/1501: What is the { award } from { Mario Puzo }, which i...
# Testing query 560/1501: When was this ancient Roman sculpture built...
# Testing query 561/1501: Who is the {literary work} for {published in} of {...
# Testing query 562/1501: Did the Foo Fighters record with RCA Records and C...
# Testing query 563/1501: Neil Armstrong was the crew member of which moon l...
# Testing query 564/1501: Is there only one platform track?...
# Testing query 565/1501: how many records are done in Los Angeles?...
# Testing query 566/1501: Is OX the safety classification and labelling of n...
# Testing query 567/1501: What is the elected office with the longest term l...
# Testing query 568/1501: What is the SoC with minimum clock speed manufactu...
# Testing query 569/1501: Name the short-chain fatty acid causing acetic aci...
# Testing query 570/1501: Where is the Greenpeace headquarters in the Nether...
# Testing query 571/1501: Do you know what human incluenced JRR Tolkien?...
# Testing query 572/1501: What is the name of the credit institution owned b...
# Testing query 573/1501: Who replaced George IV of the United Kingdom as mo...
# Testing query 574/1501: Tell me diffusion whose name has the word osmosis ...
# Testing query 575/1501: Did the Wright Brothers receive the Presidential C...
# Testing query 576/1501: What is the partner town of the place from Tomas C...
# Testing query 577/1501: Is the luminosity of the Alpha Andromedae less tha...
# Testing query 578/1501: Name an alcoholic beverage obtained by fermentatio...
# Testing query 579/1501: When did Stanislav Cherchesov start playing for FC...
# Testing query 580/1501: 1880 was the year Henry Peach Robinson founded wha...
# Testing query 581/1501: "Who is {famous for} of {Andrea Bocelli}, which ha...
# Testing query 582/1501: How many residents are in Yekaterinburg?...
# Testing query 583/1501: Which is the borough of New York City for the cate...
# Testing query 584/1501: Which enterprise is a subsidiary of Cathay Pacific...
# Testing query 585/1501: What position did Thomas Babington Macaulay, 1st B...
# Testing query 586/1501: What country has quality properties for a film fes...
# Testing query 587/1501: what is the wives of landscape of snake dance, rut...
# Testing query 588/1501: What is the Hypertext Transfer Protocol for Gariso...
# Testing query 589/1501: What position did F.W. de Klerk replace Alwyn Sche...
# Testing query 590/1501: Which county seat of Bridgetown has a member of an...
# Testing query 591/1501: Which is the Wikimedia category of the category fo...
# Testing query 592/1501: Who founded the video game publisher of the game I...
# Testing query 593/1501: Who is divorced by Ryan Reynolds in 2011?...
# Testing query 594/1501: "Which is {plays} of {ice skate}, that has {has pr...
# Testing query 595/1501: Tell me the end time for Muttiah Muralitharan has ...
# Testing query 596/1501: Which is the specialty that is studied by Nubia?...
# Testing query 597/1501: Give me a state in Australia that starts with an "...
# Testing query 598/1501: Who is the {illustrator} and the {author} of {The_...
# Testing query 599/1501: Is the borrowing rate of a Consorsbank VISA card l...
# Testing query 600/1501: What city was New Orleans twinned with in 2012?...
# Testing query 601/1501: Who is the child of the sister or the brother of M...
# Testing query 602/1501: Name a folk saint already performed by Jefferson M...
# Testing query 603/1501: Give me end time for Alexey Leonov has significant...
# Testing query 604/1501: Name a building made by the Islamic art of the Emi...
# Testing query 605/1501: What is the Fraser River coordinate locations is i...
# Testing query 606/1501: What is the population of the province where the K...
# Testing query 607/1501: What was Gregory Peck nominated for at the 18th Ac...
# Testing query 608/1501: David Hilbert was a member of what in 1932?...
# Testing query 609/1501: Is the price of the Macanese pataca equal to 0.105...
# Testing query 610/1501: ...
# Testing query 611/1501: Where is the {country of origin} and the {language...
# Testing query 612/1501: What is the series that comes before the 37th Veni...
# Testing query 613/1501: How many writing systems are there for Tagalog?...
# Testing query 614/1501: What is the Date of birth of Henry I of France?...
# Testing query 615/1501: What diatomic nonmetal has the highest oxidation s...
# Testing query 616/1501: What is Paul McCartney's language of expression wh...
# Testing query 617/1501: Who co-founded the label of Godfather Buried Alive...
# Testing query 618/1501: What is the name of the Dungeons and Dragon's publ...
# Testing query 619/1501: What are the coordinates of the source of the Kasa...
# Testing query 620/1501: Who did Edward Teller marry on February 24, 1934?...
# Testing query 621/1501: WHICH IS THE IP NETWORK THAT CONTAINS THE WORD INT...
# Testing query 622/1501: Was the net profit of Glencore greater than -6,491...
# Testing query 623/1501: Does the endowment of the University of Waterloo e...
# Testing query 624/1501: Is the precipitation height of the Kenting Nationa...
# Testing query 625/1501: Located in the administrative territorial entity o...
# Testing query 626/1501: Where was Justus von Liebig buried that is at the ...
# Testing query 627/1501: Which reservoir has the largest volume?...
# Testing query 628/1501: What is the medical usage of phenol?...
# Testing query 629/1501: For which production was Philippe Noiret the Cesar...
# Testing query 630/1501: Which Democratic Republic country was involved in ...
# Testing query 631/1501: Is the density of water equal to 0.96862?...
# Testing query 632/1501: How many software engines are used to play Wolfens...
# Testing query 633/1501: Where will the journey of the Voyager 2 spacecraft...
# Testing query 634/1501: In what fictional universe does the entity Stone T...
# ...
# Testing query 1306/1501: Who is the pianist artist of The Rise and Fall of ...
# Testing query 1307/1501: How is inertia measured?...
# Testing query 1308/1501: Who are the inhabitants of the main topic of the H...
# Testing query 1309/1501: In what subject did Linda Nochlin major while atte...
# Testing query 1310/1501: WHICH IS THE FAMILY OF ISOMERIC COMPOUNDS CONTAINS...
# Testing query 1311/1501: which type of value starts with b...
# Testing query 1312/1501: When did Lawrence Summers stop being the United St...
# Testing query 1313/1501: What award did Nikolay Cherkasov win on February 2...
# Testing query 1314/1501: What position did George II of Great Britain hold ...
# Testing query 1315/1501: According to the geolocation of -71.1247, where di...
# Testing query 1316/1501: Who replaced the position held by Bill Clinton as ...
# Testing query 1317/1501: Is Barcelona the place of Johan Cruyff's death?...
# Testing query 1318/1501: At what point in time did Rigoberta Menchu tum rec...
# Testing query 1319/1501: Name the concept in physics which caused the Big B...
# Testing query 1320/1501: The Knights Templar has how many religious orders?...
# Testing query 1321/1501: Which non-profit organization runs Wikipedia?...
# Testing query 1322/1501: How many people live on the moon of Uranus?...
# Testing query 1323/1501: In what area was Gothenburg during the end of 2010...
# Testing query 1324/1501: What is the country and the World Heritage criteri...
# Testing query 1325/1501: When did Ossie Davis graduate from Howard Universi...
# Testing query 1326/1501: What are the diagnostic test which start with the ...
# Testing query 1327/1501: Which is the border seat of Hafun Fishing Company?...
# Testing query 1328/1501: What is the minimum viable temperature for a strai...
# Testing query 1329/1501: What did FC Barcelona receive an award and nominat...
# Testing query 1330/1501: Are the ballots cast in the Catalan regional elect...
# Testing query 1331/1501: What finite group has the highest cardinality?...
# Testing query 1332/1501: Is there a correlation between the Universe and th...
# Testing query 1333/1501: when did alfred brendel received award at the time...
# Testing query 1334/1501: Who is the {public educational institution of the ...
# Testing query 1335/1501: When did Lesotho start using a flag image as the F...
# Testing query 1336/1501: Which is the Wikimedia category for the associated...
# Testing query 1337/1501: What countries does Renata Tebaldi hold citizenshi...
# Testing query 1338/1501: Name a fictional detective character inspired by T...
# Testing query 1339/1501: Who won the 1971 Wimbledon Women's Singles Champio...
# Testing query 1340/1501: When did Johannes V Jensen cease to reside in Vibo...
# Testing query 1341/1501: Name the highest snowfall total from a blizzard lo...
# Testing query 1342/1501: When will Oral stop being a member of the Russian ...
# Testing query 1343/1501: What components make up ammonia?...
# Testing query 1344/1501: Who was he leader of Niamey until 1970?...
# Testing query 1345/1501: Is the radial velocity of Messier 15 equal to -107...
# Testing query 1346/1501: Did Steve Wozniak go to college and the University...
# Testing query 1347/1501: Andres Manuel Lopez Obrador held what  position in...
# Testing query 1348/1501: When was Jacobus Henricus van 't Hoff awarded the ...
# Testing query 1349/1501: What is the occurrence with the lowest quantity wh...
# Testing query 1350/1501: What position does Iván Duque Márquez hold at 2018...
# Testing query 1351/1501: Who is the developer of Internet Protocol and what...
# Testing query 1352/1501: who academic major for field of work of Noam Choms...
# Testing query 1353/1501: Does the Motorcity have more than 1.2 seasons?...
# Testing query 1354/1501: What is the method for determining which developin...
# Testing query 1355/1501: Does the Brazillian Military Cemetery of Pustoia q...
# Testing query 1356/1501: Name an ethnic group that can be found in Norway...
# Testing query 1357/1501: The Treaty of Versailles was signed by which diplo...
# Testing query 1358/1501: What is the parent tax and the taxon of Almond?...
# Testing query 1359/1501: What are the jurisdiction which start with the let...
# Testing query 1360/1501: What is the sports season of the Chirripo National...
# Testing query 1361/1501: What country bordered the Roman Empire?...
# Testing query 1362/1501: Mention the Russian Orthodox Church's eastern orth...
# Testing query 1363/1501: Tell me type of wood whose name has the word zebra...
# Testing query 1364/1501: What is the musical score by Toccata and Fugue in ...
# Testing query 1365/1501: What position did Ferdinand Marcos hold when he wa...
# Testing query 1366/1501: Is the mains voltage of the Kiribati equal to 240?...
# Testing query 1367/1501: What are thevideo game genre which start with the ...
# Testing query 1368/1501: Is the clearance of the Gladesville Bridge greater...
# Testing query 1369/1501: Name the Kyoto, Japan's prefecture related to the ...
# Testing query 1370/1501: Name a season that includes the month of August an...
# Testing query 1371/1501: Did Led Zeppelin record with Stax?...
# Testing query 1372/1501: Who was elected rector of Leipzig University on De...
# Testing query 1373/1501: What was founded next to Krafwerk?...
# Testing query 1374/1501: Is the IDLH of the graphite less than 1500?...
# Testing query 1375/1501: Is it true that the British airways flight 9 have ...
# Testing query 1376/1501: He has three kids; Orghana,Ariq Böka, and Toqoqan....
# Testing query 1377/1501: Is it true that the flash point of zinc stearate i...
# Testing query 1378/1501: The name for the information leark for Juan Carlos...
# Testing query 1379/1501: Does the standard molar entropy of lithium equal 2...
# Testing query 1380/1501: When did the stellar rotational velocity of Draco ...
# Testing query 1381/1501: What is the time-weighted average exposure limit f...
# Testing query 1382/1501: What is the biological sex of Curtis Warren, also ...
# Testing query 1383/1501: What is the temperature of the fork in degrees Cel...
# Testing query 1384/1501: What is the isotope of hydrogen that follows deute...
# Testing query 1385/1501: What is the diplomatic relation of Carl von Ossiet...
# Testing query 1386/1501: Was Nicholas_II_of_Russia sibling Grand Duchess Ol...
# Testing query 1387/1501: What is the vapor pressure of hydrogen cyanide at ...
# Testing query 1388/1501: What edition of the Iliad is French?...
# Testing query 1389/1501: Does the cost of Dust equal to 3000?...
# Testing query 1390/1501: Who is starring in the film series of Souls of the...
# Testing query 1391/1501: Who is the diplomat of Serbia?...
# Testing query 1392/1501: What is the start time for the Santo Tomas de Aqui...
# Testing query 1393/1501: What is Salman of Saudi Arabia's hereditary title?...
# Testing query 1394/1501: How many sidekicks does the Batman have?...
# Testing query 1395/1501: What plays did the co-husband of Adéla Pollertová ...
# Testing query 1396/1501: Which was the sovereign state of the country of ci...
# Testing query 1397/1501: Tell me comedic genre whose name has the word sitc...
# Testing query 1398/1501: What dialect is commonly used in Russia?...
# Testing query 1399/1501: What was Bewitched nominated for in 1967?...
# Testing query 1400/1501: Tell me about the land registration commissioned b...
# Testing query 1401/1501: Hungary has what number of time zones contained wi...
# Testing query 1402/1501: Is the water footprint of beef more than 18498.0?...
# Testing query 1403/1501: Is it true that the proper motion of Alpha Centaur...
# Testing query 1404/1501: When was René Cassin in nomination for the Nobel P...
# Testing query 1405/1501: Tell me end time for Grodno has country as Second ...
# Testing query 1406/1501: How many names are there for Kang Youwei?...
# Testing query 1407/1501: Who did Jeff Goldblum marry in November 1987?...
# Testing query 1408/1501: What is the mascot of Georgetown University?...
# Testing query 1409/1501: In what country was the pope born in?...
# Testing query 1410/1501: Which port city is the highest point Tibidabo and ...
# Testing query 1411/1501: Who was Robert Shaw married to until 1975?...
# Testing query 1412/1501: What country is next to Tim Conway?...
# Testing query 1413/1501: Which weapon model has the longest field of view?...
# Testing query 1414/1501: What number of interactions does an up quark have?...
# Testing query 1415/1501: What scientific law did Dimitri Mendeleyev invent?...
# Testing query 1416/1501: Who follows the Catholic Church?...
# Testing query 1417/1501: Russian is the language of work or name for what o...
# Testing query 1418/1501: Who is the operator of business at CBS?...
# Testing query 1419/1501: Who is starring in Gary the Monster?...
# Testing query 1420/1501: Is 3.6 the mass of the Alpha Andromedae?...
# Testing query 1421/1501: Who died in Rome?...
# Testing query 1422/1501: Where {has local government areas} and {location o...
# Testing query 1423/1501: When did Cornel West receive his Lannan Cultural F...
# Testing query 1424/1501: What are the subsidiary entities of the United Sta...
# Testing query 1425/1501: Which vessel has the most volume that was assemble...
# Testing query 1426/1501: Name an alcohol that can interact with Potassium i...
# Testing query 1427/1501: What is the end time named after Oghuz Khagan that...
# Testing query 1428/1501: What city in Mumbai houses it's administrative bod...
# Testing query 1429/1501: What country was abolished in Kirovohrad oblast in...
# Testing query 1430/1501: Is the residence time of the water in Lake Maggior...
# Testing query 1431/1501: Is the lower limit of the set of non-negative inte...
# Testing query 1432/1501: What is the name of the book classified in encyclo...
# Testing query 1433/1501: WHat is the highest position in theUnited States E...
# Testing query 1434/1501: Tell me type of number  whose name has the word nu...
# Testing query 1435/1501: Who gave the {on harbour} of {player} of {Gallipol...
# Testing query 1436/1501: For what John Elway was in nomination in the year ...
# Testing query 1437/1501: Which country has the highest nominal GDP per capi...
# Testing query 1438/1501: Name the developer of Fresnel lens, who graduated ...
# Testing query 1439/1501: What is the {sexual orientation} and the {sex or g...
# Testing query 1440/1501: For what work did Isaac Asimov receive the Nebula ...
# Testing query 1441/1501: When did Bob Woodward receive the award Worth Bing...
# Testing query 1442/1501: How much product materials are being produced by t...
# Testing query 1443/1501: When did Seoul become a sister city with Tokyo?...
# Testing query 1444/1501: Which was the person as doctoral student of Galile...
# Testing query 1445/1501: What is Kabul the capital of?...
# Testing query 1446/1501: Which is {award received} by {pupil} of {Enrico Fe...
# Testing query 1447/1501: Which is the common-law wife of dedicatee of Templ...
# Testing query 1448/1501: "What administrative unit did Arthur M. Schlesinge...
# Testing query 1449/1501: What award did Robin Williams and Christine Barans...
# Testing query 1450/1501: Tell me the series ordinal for John Greenleaf Whit...
# Testing query 1451/1501: What body of water borders B-29 Serial No. 45-2184...
# Testing query 1452/1501: Which is the memoir that is the notable work of Hi...
# Testing query 1453/1501: Which video game company developed Pong?...
# Testing query 1454/1501: What award did José Echegaray get in 1911?...
# Testing query 1455/1501: For what movie was Otto Preminger nominated for Ac...
# Testing query 1456/1501: Which is {heritage designation} of {administrative...
# Testing query 1457/1501: Is it true that the century breaks of Jak Jones ar...
# Testing query 1458/1501: Who replaced Samuel Taliaferro Rayburn as Dean of ...
# Testing query 1459/1501: At what point in time did Apple Inc. report a net ...
# Testing query 1460/1501: When was Ganja a part of Azerbaijan?...
# Testing query 1461/1501: Give me the name of the space mission that was lau...
# Testing query 1462/1501: Who in starring film High Noon has died from kidne...
# Testing query 1463/1501: Which is the mathematical concept which contains t...
# Testing query 1464/1501: Which is the currency for the country of Biafra?...
# Testing query 1465/1501: When did Chongqing and Mpumalanga become sister ci...
# Testing query 1466/1501: What was the co-founder of Walsh University found ...
# Testing query 1467/1501: what is executive director of developed by of ios?...
# Testing query 1468/1501: What districts of Saitama have the gps coordinates...
# Testing query 1469/1501: How many sources of energy are natural gas?...
# Testing query 1470/1501: What was Piers Anthony nominated for that's work i...
# Testing query 1471/1501: The stock exchange rate of Nintendo is ticker symb...
# Testing query 1472/1501: What is the subtopic of Universal Decimal Classifi...
# Testing query 1473/1501: Which is the fictional universe that takes place i...
# Testing query 1474/1501: Who did Alfred Kinsey divorce in 1956?...
# Testing query 1475/1501: What did Christie Brinkley's husband say...
# Testing query 1476/1501: Is it true that the number of deaths of D. B. Coop...
# Testing query 1477/1501: Purdue University is the parent organization of wh...
# Testing query 1478/1501: Is the mean anomaly of 3149 Okudzhava equal to 3.8...
# Testing query 1479/1501: When did Pausanias die?...
# Testing query 1480/1501: ...
# Testing query 1481/1501: Tell me which is the administrative territorial en...
# Testing query 1482/1501: Who uses Pro Evolution Soccer?...
# Testing query 1483/1501: Who competed in Doc Holliday?...
# Testing query 1484/1501: When did Jules Verne attend lycee Georges-Clemence...
# Testing query 1485/1501: Which is the dissolution of an administrative terr...
# Testing query 1486/1501: Which billionaire has the highest net worth estima...
# Testing query 1487/1501: Is the shear modulus of diamond less than 573.6?...
# Testing query 1488/1501: Who is also known as Gürcü Hatun and contains the ...
# Testing query 1489/1501: What is the lethal dose of ketone?...
# Testing query 1490/1501: In which serial ordinal was Eudoxia Lopukhina was ...
# Testing query 1491/1501: What Microsoft Mobile smartphone has the largest b...
# Testing query 1492/1501: What is coordinate location  of  Elbe  that  appli...
# Testing query 1493/1501: What is the name of the "sister city" tied to Kans...
# Testing query 1494/1501: What is the hight of  the studio where filmed of T...
# Testing query 1495/1501: When did the Democratic Republic of Congo begin us...
# Testing query 1496/1501: Whose findspot is nobium who has a total fertility...
# Testing query 1497/1501: Which {category of associated people} of {sister c...
# Testing query 1498/1501: which song starts with the letter w...
# Testing query 1499/1501: What was the award of Trondheim received in 2008?...
# Testing query 1500/1501: What physical quantity is measured in joules?...
# Testing query 1501/1501: does the Papuzhintsi area equals 0.0?...
#
# === VALIDATION SUMMARY ===
# Total queries: 1501
# Valid (return results): 1028 (68.5%)
# Invalid (no results): 473 (31.5%)
#
# First few invalid queries:
# - Q: question...
#   Error: HTTP 400: SPARQL-QUERY: queryStr=sparql_wikidata LIMIT 100
# java.util.concurrent.ExecutionException: org.openrdf.query.MalformedQueryException: Lexical error at line 1, column 16.  Encountered: " " (32), after :
#
# - Q: What Blood test Specialty Type for Academy....
#   Error: No results returned
#
# - Q: Name of the statuette with the lowest thickness which has Ar...
#   Error: No results returned
#
# - Q: What what isazane has effect by ammonia exposureand also whi...
#   Error: No results returned
#
# - Q: Are Basra and Kitwe twinned administrative bodies in Detroit...
#   Error: HTTP 400: SPARQL-QUERY: queryStr=ASK WHERE { wd:Q12439 wdt:P190 wd:Q48195 . wd:Q12439 wdt:P190 wd:Q239580 } LIMIT 100
# java.util.concurrent.ExecutionException: org.openrdf.query.MalformedQueryException: Encounte
#
# Results saved to validation_results_20250623_123305.csv
# Results saved to invalid_queries_20250623_123305.csv
# Invalid queries saved separately to invalid_queries_20250623_123305.csv
