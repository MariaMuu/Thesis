# %% [markdown]
# <a href="https://colab.research.google.com/github/MariaMuu/Thesis/blob/main/wikidata_api.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %pip install --upgrade --quiet wikibase-rest-api-client mediawikiapi
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.2/110.2 kB 4.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 45.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.3/42.3 kB 2.3 MB/s eta 0:00:00

# %%
# %pip install langchain.community
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 38.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.2/45.2 kB 3.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.9/50.9 kB 3.9 MB/s eta 0:00:00
# ...

# %%
from langchain_community.tools.wikidata.tool import WikidataAPIWrapper, WikidataQueryRun

wikidata = WikidataQueryRun(api_wrapper=WikidataAPIWrapper())

print(wikidata.run("bitcoin"))
# Out:
# Result Q131723:
# Label: bitcoin
# Description: digital cash system and associated currency
# Aliases: BTC, XBT, ₿, Bitcoins, Bitcoin
# instance of: free software, communication protocol, blockchain, currency, reserve currency, crypto asset, cryptocurrency, legal tender, payment system
# subclass of: investment
# has part(s): bitcoin blockchain, bitcoin protocol
# country: El Salvador, Central African Republic
# publication date: 2009-01-03
# inception: 2009-01-03
# developer: Satoshi Nakamoto
#
# Result Q122824486:
# Label: Bitcoin
# Description: 2018 video game
# instance of: video game
# publication date: 2018-11-12
# genre: casual game, simulation video game
# developer: RewindApp
